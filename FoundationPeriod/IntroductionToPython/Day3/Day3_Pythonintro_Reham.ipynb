# %% [markdown]
# ### Stars that where in lab1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
spaces=4
cha='*'
count_star=1
for i in range(1,6):
  print(" "*spaces+ count_star*cha+spaces*" ")
  spaces-=1
  count_star+=2
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
spaces=4
cha='*'
count_star=1
for i in range(1,5):
  print(" "*spaces+ count_star*cha+spaces*" ")
  spaces-=1
  count_star+=2
  #print(count_star)
spaces=0

for i in range(6,11):
  print(" "*spaces+ count_star*cha+spaces*" ")
  spaces+=1
  count_star-=2
  #print(count_star)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %% [markdown]
# # Day 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Vehicle:
  def __init__(self,name,max_speed,mileage):
    self.name=name
    self.max_speed=max_speed
    self.mileage=mileage
  def prnt(self):
    print("Vehicle Name: {} Speed: {} Mileage: {}".format(self.name,self.max_speed,self.mileage))
  def seating_capacity(self,capacity):
    return f'The seating capacity of a {self.name} is {capacity} passengers'
  

class Bus(Vehicle):
   def seating_capacity(self,capacity=50):
    return f'The seating capacity of a {self.name} is {capacity} passengers'
Volvo=Bus('School Volvo',180,12)
Volvo.prnt()
# Out:
# Vehicle Name: School Volvo Speed: 180 Mileage: 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Volvo.seating_capacity()
# Out:
# 'The seating capacity of a School Volvo is 50 passengers'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Vehicle:
  def __init__(self,name,mileage,capacity):
    self.name=name
    self.capacity=capacity
    self.mileage=mileage
  def fare(self):
    return self.capacity *100
  

class Bus(Vehicle):
    def fare(self):
      return self.capacity * 100 + 0.1* self.capacity * 100
School_buss=Bus('School Volvo',12,50)
print("Total Bus fare is: ",School_buss.fare())
# Out:
# Total Bus fare is:  5500.0
